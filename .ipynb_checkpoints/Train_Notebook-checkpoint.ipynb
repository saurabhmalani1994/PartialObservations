# %%
from utils import config
import train_model

train_model.main(config)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Using dt of 0.0049999999999999906
#   0%|          | 0/10 [00:00<?, ?it/s]
# Using dt of 0.0049999999999999906
#   0%|          | 0/1 [00:00<?, ?it/s]
# Using dt of 0.0049999999999999906
# Network(
#   (layers): ModuleList(
#     (0): Linear(in_features=2, out_features=64, bias=True)
#     (1): Linear(in_features=64, out_features=1, bias=True)
#   )
#   (activation): Tanh()
#   (sigmoid): Sigmoid()
# )
# ModuleList(
#   (0): Linear(in_features=2, out_features=64, bias=True)
#   (1): Linear(in_features=64, out_features=1, bias=True)
# )
# Using: cuda
# Trainable parameters: 257
# Train/Loss: 0.00e+00  Val/Loss: 0.00e+00:   0%|          | 0/2000 [00:00<?, ?it/s]
