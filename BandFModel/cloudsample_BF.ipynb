# %%
# %cd /home/smalani/PartialObservations
from config import config
from BandFModel import datagen#
import numpy as np
# Out:
# /home/smalani/PartialObservations

# %%
data_val = datagen.generate_data(n_train=1000, 
                  tmax=200, 
                  sf=config["PAR"]["sf"],                   
                  x_sample_num=(np.array([10, 10, 10, 10, 10, 10])).astype(int),
                  skip_time=100,
                  reg_time=True,
                  dt_dist=(config["DATA"]["DT_MU"],
                           config["DATA"]["DT_SIGMA"]),
                  init_available=True,
                  full_observations=True,
                  theta_random=False,
                  detail=True,
                  theta_set=7.3,
                  duplicate_reverse=False
                 )
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# pakapaaakaaa detail
# (10, 6)

# %%
mydata = data_val[3].copy()[:,::100,:].reshape((-1,6))
print(mydata.shape)

f = np.load('/home/smalani/PartialObservations/minmax/limitcycle_detail.npz')
myvar0_detail = f['arr_0']

print(myvar0_detail.shape)
# Out:
# (100, 6)
# (6, 1000)

# %%
# np.save("minmax/cloudsamplepoints",mydata)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(myvar0_detail[2,:],myvar0_detail[0,:],'k-')
plt.scatter(mydata[:,2],mydata[:,0], color='b', s=1)
plt.xlabel('z')
plt.ylabel('x')

plt.figure()
plt.plot(myvar0_detail[5,:],myvar0_detail[0,:],'k-')
plt.scatter(mydata[:,5],mydata[:,0], color='b', s=1)
plt.xlabel('g')
plt.ylabel('x')
# Out:
# Text(0, 0.5, 'x')
