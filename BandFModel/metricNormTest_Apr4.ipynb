# %%
# %cd /home/smalani/PartialObservations

from BandFModel import plot_and_metric_BandF
# Out:
# /home/smalani/PartialObservations

# %%
## Black Box Trainable Metrics

# %cd /home/smalani/PartialObservations
from BandFModel import plot_and_metric_BandF
import numpy as np

# RHS Hairs
L1_error_arr = []
L2_error_arr = []
Linf_error_arr = []


from config import config
config["MODEL"]["BOX"] = 'Black'
config["MODEL"]["Parameters"] = 'Fixed'

for i in range(10):
    filename = "/home/smalani/PartialObservations/data/blackbox/model_run_" + str(i) + ".net"

    RHS_hair_error_trueLC_True, RHS_hair_error_trueLC_Pred, L1_error, L2_error, Linf_error = \
        plot_and_metric_BandF.metric_hair_fromTrue(filename=filename, make_plots=False)
    # print('===============================')
    # print(root_pred)
    # print('===============================')

    L1_error_arr.append(L1_error)
    L2_error_arr.append(L2_error)
    Linf_error_arr.append(Linf_error)

BB_bestcase = np.argmin(L2_error_arr)
print("BEST BLACK BOX RUN")
print(BB_bestcase)


print("Black Box Solution Errors")
print(np.average(L1_error_arr))
print(np.std(L1_error_arr))
print('===============')
print(np.average(L2_error_arr))
print(np.std(L2_error_arr))
print('===============')
print(np.average(Linf_error_arr))
print(np.std(Linf_error_arr))

L1_error_arr = []
L2_error_arr = []
Linf_error_arr = []

for i in range(10):
    filename = "/home/smalani/PartialObservations/data/blackbox/model_run_" + str(i) + ".net"

    root_pred = None
    output, ANN_output, output_LC, ANN_output_LC, L1_error, L2_error, Linf_error = \
        plot_and_metric_BandF.metric_RHS(filename=filename, make_plots=False)
    # print('===============================')
    # print(root_pred)
    # print('===============================')

    L1_error_arr.append(L1_error)
    L2_error_arr.append(L2_error)
    Linf_error_arr.append(Linf_error)

print("Black Box RHS Errors")
print(np.average(L1_error_arr))
print(np.std(L1_error_arr))
print('===============')
print(np.average(L2_error_arr))
print(np.std(L2_error_arr))
print('===============')
print(np.average(Linf_error_arr))
print(np.std(Linf_error_arr))
# Out:
# /home/smalani/PartialObservations
# /home/smalani/PartialObservations/data/blackbox/model_run_0.net
# /home/smalani/PartialObservations/data/blackbox/model_run_1.net
# /home/smalani/PartialObservations/data/blackbox/model_run_2.net
# /home/smalani/PartialObservations/data/blackbox/model_run_3.net
# /home/smalani/PartialObservations/data/blackbox/model_run_4.net
# /home/smalani/PartialObservations/data/blackbox/model_run_5.net
# /home/smalani/PartialObservations/data/blackbox/model_run_6.net
# /home/smalani/PartialObservations/data/blackbox/model_run_7.net
# /home/smalani/PartialObservations/data/blackbox/model_run_8.net
# /home/smalani/PartialObservations/data/blackbox/model_run_9.net
# BEST BLACK BOX RUN
# 9
# Black Box Solution Errors
# 0.006261360760266789
# 0.0008135583178667856
# ===============
# 0.003253400502394664
# 0.0004270097615080431
# ===============
# 0.013609851836202188
# 0.0017180204009297553
# /home/smalani/PartialObservations/data/blackbox/model_run_0.net
# /home/smalani/PartialObservations/data/blackbox/model_run_1.net
# /home/smalani/PartialObservations/data/blackbox/model_run_2.net
# /home/smalani/PartialObservations/data/blackbox/model_run_3.net
# /home/smalani/PartialObservations/data/blackbox/model_run_4.net
# /home/smalani/PartialObservations/data/blackbox/model_run_5.net
# /home/smalani/PartialObservations/data/blackbox/model_run_6.net
# /home/smalani/PartialObservations/data/blackbox/model_run_7.net
# /home/smalani/PartialObservations/data/blackbox/model_run_8.net
# /home/smalani/PartialObservations/data/blackbox/model_run_9.net
# Black Box RHS Errors
# 0.003998245828764924
# 0.0007745861719111133
# ===============
# 0.0021233164538174256
# 0.00044558769952366057
# ===============
# 0.007133688326369916
# 0.001280579116986785

# %%
import matplotlib.pyplot as plt 

filename = "/home/smalani/PartialObservations/data/blackbox/model_run_" + str(BB_bestcase) + ".net"

output, ANN_output, output_LC, ANN_output_LC, L1_error, L2_error, Linf_error = \
        plot_and_metric_BandF.metric_RHS(filename=filename, make_plots=False)

fig = plt.figure(figsize=(15,10))

labels = ['$\dot{x}$', '$\dot{y}$', '$\dot{z}$', '$\dot{u}$', '$\dot{v}$', '$\dot{g}$']
for i in range(6):
    ax = plt.subplot(int(str(23) + str(i+1)))
    axplot = ax.scatter(output[:,i], ANN_output[:,i], s=4)
    # axplot = ax.scatter(output_LC[:,i], ANN_output_LC[:,i], s=4)
    ax.plot([np.min(output[:,i]), np.max(output[:,i])],[np.min(output[:,i]), np.max(output[:,i])], 'k-')
    # ax.tick_params(axis='y', labelsize=20)
    ax.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
    ax.yaxis.offsetText.set_fontsize(15)
    ax.tick_params(axis='both', labelsize=30, direction='in', length=10, width=2)
    ax.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
    ax.xaxis.offsetText.set_fontsize(15)
    ax.set_title(labels[i], fontsize=30)
    ax.set_aspect("equal", adjustable="datalim")

# plt.suptitle('Predicted RHS vs True RHS', fontsize=40)

fig.supylabel('Predicted RHS', fontsize=30)
fig.supxlabel('True RHS', fontsize=30)
plt.tight_layout()
plt.savefig('Figures/blackbox/BB_RHS_Prediction_Model_Run_' + str(BB_bestcase) + '.png')

plot_and_metric_BandF.make_poincare_maps(filename, make_plots=True, savefilename = 'Figures/blackbox/BB_LC_Prediction_Model_Run_' + str(BB_bestcase) + '.png')
# Out:
# /home/smalani/PartialObservations/data/blackbox/model_run_9.net
# /home/smalani/PartialObservations/data/blackbox/model_run_9.net
# My guess
# [5.00748680e+01 5.47858451e-06 3.45266033e-01 8.95880507e+01
#  1.51907866e+03 7.91971631e-01]

# %%
## Grey Box Fixed Trainable Metrics

# %cd /home/smalani/PartialObservations
from BandFModel import plot_and_metric_BandF
import numpy as np

# RHS Hairs
L1_error_arr = []
L2_error_arr = []
Linf_error_arr = []


from config import config
config["MODEL"]["BOX"] = 'Grey'
config["MODEL"]["Parameters"] = 'Fixed'

for i in range(10):
    filename = "/home/smalani/PartialObservations/data/greybox_fixed/model_run_" + str(i) + ".net"

    RHS_hair_error_trueLC_True, RHS_hair_error_trueLC_Pred, L1_error, L2_error, Linf_error = \
        plot_and_metric_BandF.metric_hair_fromTrue(filename=filename, make_plots=False)
    # print('===============================')
    # print(root_pred)
    # print('===============================')

    L1_error_arr.append(L1_error)
    L2_error_arr.append(L2_error)
    Linf_error_arr.append(Linf_error)

GB1_bestcase = np.argmin(L2_error_arr)
print("BEST GREY BOX FIXED RUN")
print(GB1_bestcase)


print("Grey Box Fixed Solution Errors")
print(np.average(L1_error_arr))
print(np.std(L1_error_arr))
print('===============')
print(np.average(L2_error_arr))
print(np.std(L2_error_arr))
print('===============')
print(np.average(Linf_error_arr))
print(np.std(Linf_error_arr))


L1_error_arr = []
L2_error_arr = []
Linf_error_arr = []

for i in range(10):
    filename = "/home/smalani/PartialObservations/data/greybox_fixed/model_run_" + str(i) + ".net"

    root_pred = None
    output, ANN_output, output_LC, ANN_output_LC, L1_error, L2_error, Linf_error = \
        plot_and_metric_BandF.metric_RHS(filename=filename, make_plots=False)
    # print('===============================')
    # print(root_pred)
    # print('===============================')

    L1_error_arr.append(L1_error)
    L2_error_arr.append(L2_error)
    Linf_error_arr.append(Linf_error)

print("Grey Box Fixed RHS Errors")
print(np.average(L1_error_arr))
print(np.std(L1_error_arr))
print('===============')
print(np.average(L2_error_arr))
print(np.std(L2_error_arr))
print('===============')
print(np.average(Linf_error_arr))
print(np.std(Linf_error_arr))

L1_error_arr = []
L2_error_arr = []
Linf_error_arr = []

for i in range(10):
    filename = "/home/smalani/PartialObservations/data/greybox_fixed/model_run_" + str(i) + ".net"

    phi_true, phi_pred, L1_error, L2_error, Linf_error = \
    plot_and_metric_BandF.metric_phi(filename=filename, make_plots=False)

    L1_error_arr.append(L1_error)
    L2_error_arr.append(L2_error)
    Linf_error_arr.append(Linf_error)

print("Grey Box Fixed Phi Errors")
print(np.average(L1_error_arr))
print(np.std(L1_error_arr))
print('===============')
print(np.average(L2_error_arr))
print(np.std(L2_error_arr))
print('===============')
print(np.average(Linf_error_arr))
print(np.std(Linf_error_arr))
# Out:
# /home/smalani/PartialObservations
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_0.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_1.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_2.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_3.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_4.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_5.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_6.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_7.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_8.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_9.net
# BEST GREY BOX FIXED RUN
# 6
# Grey Box Fixed Solution Errors
# 0.010426533717851284
# 0.0015371413193134157
# ===============
# 0.005159956055871428
# 0.0006838836969598963
# ===============
# 0.018988735997079183
# 0.002404689041081369
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_0.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_1.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_2.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_3.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_4.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_5.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_6.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_7.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_8.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_9.net
# Grey Box Fixed RHS Errors
# 0.009944003483214068
# 0.0014094398608689282
# ===============
# 0.005426733407052763
# 0.0008025782979581411
# ===============
# 0.0168262908866847
# 0.0022583092839934525
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_0.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_1.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_2.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_3.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_4.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_5.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_6.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_7.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_8.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_9.net
# Grey Box Fixed Phi Errors
# 0.001017065836631861
# 0.00014148128012491176
# ===============
# 0.0007663761865807748
# 0.00011409829342079671
# ===============
# 0.0012357152375155032
# 0.00016571963572654656

# %%
import matplotlib.pyplot as plt 

filename = "/home/smalani/PartialObservations/data/greybox_fixed/model_run_" + str(GB1_bestcase) + ".net"

phi_true, phi_pred, L1_error, L2_error, Linf_error = \
plot_and_metric_BandF.metric_phi(filename=filename, make_plots=False)

output, ANN_output, output_LC, ANN_output_LC, L1_error, L2_error, Linf_error = \
        plot_and_metric_BandF.metric_RHS(filename=filename, make_plots=False)

fig = plt.figure(figsize=(15,5))

labels = ['$\mu_1\cdot x$', '$\mu_2\cdot y$', '$\mu_3\cdot z$']
for i in range(3):
    ax = plt.subplot(int(str(13) + str(i+1)))
    axplot = ax.scatter(phi_true[:,i], phi_pred[:,i], s=4)
    # axplot = ax.scatter(output_LC[:,i], ANN_output_LC[:,i], s=4)
    ax.plot([np.min(phi_true[:,i]), np.max(phi_true[:,i])],[np.min(phi_true[:,i]), np.max(phi_true[:,i])], 'k-')
    # ax.tick_params(axis='y', labelsize=20)
    ax.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
    ax.yaxis.offsetText.set_fontsize(15)
    ax.tick_params(axis='both', labelsize=30, direction='in', length=10, width=2)
    ax.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
    ax.xaxis.offsetText.set_fontsize(15)
    plt.title(labels[i], fontsize=30)
    ax.set_aspect("equal", adjustable="datalim")

# plt.suptitle('Predicted RHS vs True RHS', fontsize=40)

fig.supylabel('Predicted', fontsize=30)
fig.supxlabel('True', fontsize=30)
plt.tight_layout()
plt.savefig('Figures/greybox_fixed/GB1_Phi_Prediction_Model_Run_' + str(GB1_bestcase) + '.png')

fig = plt.figure(figsize=(15,10))

labels = ['$\dot{x}$', '$\dot{y}$', '$\dot{z}$', '$\dot{u}$', '$\dot{v}$', '$\dot{g}$']
for i in range(6):
    ax = plt.subplot(int(str(23) + str(i+1)))
    axplot = ax.scatter(output[:,i], ANN_output[:,i], s=4)
    # axplot = ax.scatter(output_LC[:,i], ANN_output_LC[:,i], s=4)
    ax.plot([np.min(output[:,i]), np.max(output[:,i])],[np.min(output[:,i]), np.max(output[:,i])], 'k-')
    # ax.tick_params(axis='y', labelsize=20)
    ax.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
    ax.yaxis.offsetText.set_fontsize(15)
    ax.tick_params(axis='both', labelsize=30, direction='in', length=10, width=2)
    ax.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
    ax.xaxis.offsetText.set_fontsize(15)
    ax.set_title(labels[i], fontsize=30)
    ax.set_aspect("equal", adjustable="datalim")

# plt.suptitle('Predicted RHS vs True RHS', fontsize=40)

fig.supylabel('Predicted RHS', fontsize=30)
fig.supxlabel('True RHS', fontsize=30)
plt.tight_layout()
plt.savefig('Figures/greybox_fixed/GB1_RHS_Prediction_Model_Run_' + str(GB1_bestcase) + '.png')

plot_and_metric_BandF.make_poincare_maps(filename, make_plots=True, savefilename = 'Figures/greybox_fixed/GB1_LC_Prediction_Model_Run_' + str(GB1_bestcase) + '.png')
# Out:
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_6.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_6.net
# /home/smalani/PartialObservations/data/greybox_fixed/model_run_6.net
# My guess
# [ 5.00119330e+01 -1.17204812e-04  2.85291765e-01  1.19785836e+02
#   1.25794610e+03  6.62791890e-01]

# %%
## Grey Box Trainable Trainable Metrics

# %cd /home/smalani/PartialObservations
from BandFModel import plot_and_metric_BandF
import numpy as np

# RHS Hairs
L1_error_arr = []
L2_error_arr = []
Linf_error_arr = []


from config import config
config["MODEL"]["BOX"] = 'Grey'
config["MODEL"]["Parameters"] = 'Trainable'

for i in range(10):
    filename = "/home/smalani/PartialObservations/data/greybox_trainable/model_run_" + str(i) + ".net"

    RHS_hair_error_trueLC_True, RHS_hair_error_trueLC_Pred, L1_error, L2_error, Linf_error = \
        plot_and_metric_BandF.metric_hair_fromTrue(filename=filename, make_plots=False)
    # print('===============================')
    # print(root_pred)
    # print('===============================')

    L1_error_arr.append(L1_error)
    L2_error_arr.append(L2_error)
    Linf_error_arr.append(Linf_error)

GB2_bestcase = np.argmin(L2_error_arr)
print("BEST GREY BOX TRAINABLE RUN")
print(GB2_bestcase)


print("Grey Box Trainable Solution Errors")
print(np.average(L1_error_arr))
print(np.std(L1_error_arr))
print('===============')
print(np.average(L2_error_arr))
print(np.std(L2_error_arr))
print('===============')
print(np.average(Linf_error_arr))
print(np.std(Linf_error_arr))

L1_error_arr = []
L2_error_arr = []
Linf_error_arr = []

for i in range(10):
    filename = "/home/smalani/PartialObservations/data/greybox_trainable/model_run_" + str(i) + ".net"

    root_pred = None
    output, ANN_output, output_LC, ANN_output_LC, L1_error, L2_error, Linf_error = \
        plot_and_metric_BandF.metric_RHS(filename=filename, make_plots=False)
    # print('===============================')
    # print(root_pred)
    # print('===============================')

    L1_error_arr.append(L1_error)
    L2_error_arr.append(L2_error)
    Linf_error_arr.append(Linf_error)

print("Grey Box Trainable RHS Errors")
print(np.average(L1_error_arr))
print(np.std(L1_error_arr))
print('===============')
print(np.average(L2_error_arr))
print(np.std(L2_error_arr))
print('===============')
print(np.average(Linf_error_arr))
print(np.std(Linf_error_arr))

L1_error_arr = []
L2_error_arr = []
Linf_error_arr = []

for i in range(10):
    filename = "/home/smalani/PartialObservations/data/greybox_trainable/model_run_" + str(i) + ".net"

    phi_true, phi_pred, L1_error, L2_error, Linf_error = \
    plot_and_metric_BandF.metric_phi(filename=filename, make_plots=False)

    L1_error_arr.append(L1_error)
    L2_error_arr.append(L2_error)
    Linf_error_arr.append(Linf_error)

print("Grey Box Trainable Phi Errors")
print(np.average(L1_error_arr))
print(np.std(L1_error_arr))
print('===============')
print(np.average(L2_error_arr))
print(np.std(L2_error_arr))
print('===============')
print(np.average(Linf_error_arr))
print(np.std(Linf_error_arr))

error_arr = []

for i in range(10):
# i=3

    filename = "/home/smalani/PartialObservations/data/greybox_trainable/model_run_" + str(i) + ".net"

    true_pars, pred_pars, error = \
    plot_and_metric_BandF.metric_exppar(filename=filename, make_plots=False)

    error_arr.append(error)

print("Grey Box Exp Par Errors")
print(np.average(error_arr))
print(np.std(error_arr))
# Out:
# /home/smalani/PartialObservations
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_0.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_1.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_2.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_3.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_4.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_5.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_6.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_7.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_8.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_9.net
# BEST GREY BOX TRAINABLE RUN
# 0
# Grey Box Trainable Solution Errors
# 0.012172229021235173
# 0.005724006394427235
# ===============
# 0.006104628070397617
# 0.0027214006159178112
# ===============
# 0.023343301545091462
# 0.010873944931087691
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_0.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_1.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_2.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_3.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_4.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_5.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_6.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_7.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_8.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_9.net
# Grey Box Trainable RHS Errors
# 0.013691646747094596
# 0.006034890701490984
# ===============
# 0.007504842559725611
# 0.0031967143607937905
# ===============
# 0.024736486883841627
# 0.014780816045612386
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_0.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_1.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_2.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_3.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_4.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_5.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_6.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_7.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_8.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_9.net
# Grey Box Trainable Phi Errors
# 0.001480069821288925
# 0.0007062818804967648
# ===============
# 0.0010918167120648945
# 0.0004887490020088169
# ===============
# 0.0017924040131672165
# 0.0011734047760878603
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_0.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_1.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_2.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_3.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_4.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_5.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_6.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_7.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_8.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_9.net
# Grey Box Exp Par Errors
# 0.0751100428849161
# 0.021034725455655438

# %%
minindex = [9 ,6 , 0]

# %%
import matplotlib.pyplot as plt 

filename = "/home/smalani/PartialObservations/data/greybox_trainable/model_run_" + str(GB2_bestcase) + ".net"

phi_true, phi_pred, L1_error, L2_error, Linf_error = \
plot_and_metric_BandF.metric_phi(filename=filename, make_plots=False)

output, ANN_output, output_LC, ANN_output_LC, L1_error, L2_error, Linf_error = \
        plot_and_metric_BandF.metric_RHS(filename=filename, make_plots=False)

fig = plt.figure(figsize=(15,5))

labels = ['$\mu_1\cdot x$', '$\mu_2\cdot y$', '$\mu_3\cdot z$']
for i in range(3):
    ax = plt.subplot(int(str(13) + str(i+1)))
    axplot = ax.scatter(phi_true[:,i], phi_pred[:,i], s=4)
    # axplot = ax.scatter(output_LC[:,i], ANN_output_LC[:,i], s=4)
    ax.plot([np.min(phi_true[:,i]), np.max(phi_true[:,i])],[np.min(phi_true[:,i]), np.max(phi_true[:,i])], 'k-')
    # ax.tick_params(axis='y', labelsize=20)
    ax.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
    ax.yaxis.offsetText.set_fontsize(15)
    ax.tick_params(axis='both', labelsize=30, direction='in', length=10, width=2)
    ax.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
    ax.xaxis.offsetText.set_fontsize(15)
    plt.title(labels[i], fontsize=30)
    ax.set_aspect("equal", adjustable="datalim")

# plt.suptitle('Predicted RHS vs True RHS', fontsize=40)

fig.supylabel('Predicted', fontsize=30)
fig.supxlabel('True', fontsize=30)
plt.tight_layout()
plt.savefig('Figures/greybox_trainable/GB2_Phi_Prediction_Model_Run_' + str(GB2_bestcase) + '.png')

fig = plt.figure(figsize=(15,10))

labels = ['$\dot{x}$', '$\dot{y}$', '$\dot{z}$', '$\dot{u}$', '$\dot{v}$', '$\dot{g}$']
for i in range(6):
    ax = plt.subplot(int(str(23) + str(i+1)))
    axplot = ax.scatter(output[:,i], ANN_output[:,i], s=4)
    # axplot = ax.scatter(output_LC[:,i], ANN_output_LC[:,i], s=4)
    ax.plot([np.min(output[:,i]), np.max(output[:,i])],[np.min(output[:,i]), np.max(output[:,i])], 'k-')
    # ax.tick_params(axis='y', labelsize=20)
    ax.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
    ax.yaxis.offsetText.set_fontsize(15)
    ax.tick_params(axis='both', labelsize=30, direction='in', length=10, width=2)
    ax.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
    ax.xaxis.offsetText.set_fontsize(15)
    ax.set_title(labels[i], fontsize=30)
    ax.set_aspect("equal", adjustable="datalim")

# plt.suptitle('Predicted RHS vs True RHS', fontsize=40)

fig.supylabel('Predicted RHS', fontsize=30)
fig.supxlabel('True RHS', fontsize=30)
plt.tight_layout()
plt.savefig('Figures/greybox_trainable/GB2_RHS_Prediction_Model_Run_' + str(GB2_bestcase) + '.png')

plot_and_metric_BandF.make_poincare_maps(filename, make_plots=True, savefilename = 'Figures/greybox_trainable/GB2_LC_Prediction_Model_Run_' + str(GB2_bestcase) + '.png')

true_pars, pred_pars, error = plot_and_metric_BandF.metric_exppar(filename, make_plots=True)

width=0.35

fig = plt.figure(figsize=(14,8))
ax = fig.add_subplot(141)
ax.bar(-width/1.8,[true_pars[0]], color='k', width=width,label='Ground Truth')
ax.bar(width/1.8,[pred_pars[0]], color='b',
        width=width, label='Model Prediction')
ax.set_xticks([0])
ax.tick_params(axis='both', labelsize=30, direction='in', length=10, width=2)
# ax.set_yscale('log')
ax.set_ylim(bottom=0.0)
ax.set_xticklabels([r"$\omega$"],fontsize=30)
plt.yticks(fontsize=30)

ax = fig.add_subplot(142)
ax.bar(-width/1.8,[true_pars[1]], color='k',width=width,label='Ground Truth')
ax.bar(width/1.8,[pred_pars[1]], color='b',
        width=width,label='Model Prediction')
ax.tick_params(axis='both', labelsize=30, direction='in', length=10, width=2)
ax.set_xticks([0])
# ax.set_yscale('log')
ax.set_ylim(bottom=0.0)
ax.set_xticklabels([r"$\sigma$"],fontsize=30)
plt.yticks(fontsize=30)

ax = fig.add_subplot(143)
ax.bar(-width/1.8,[true_pars[2]], color='k',width=width,label='Ground Truth')
ax.bar(width/1.8,[pred_pars[2]], color='b',
        width=width,label='Model Prediction')
ax.set_xticks([0])
ax.tick_params(axis='both', labelsize=30, direction='in', length=10, width=2)
# ax.set_yscale('log')
ax.set_ylim(bottom=0.0)
ax.set_xticklabels([r"$\rho$"],fontsize=30)
plt.yticks(fontsize=30)

ax = fig.add_subplot(144)
ax.bar(-width/1.8,[true_pars[3]], color='k',width=width,label='Ground Truth')
ax.bar(width/1.8,[pred_pars[3]], color='b',
        width=width,label='Model Prediction')
ax.set_xticks([0])
ax.tick_params(axis='both', labelsize=30, direction='in', length=10, width=2)
# ax.set_yscale('log')
ax.set_ylim(bottom=0.0)
ax.set_xticklabels([r"$\eta$"],fontsize=30)
plt.yticks(fontsize=30)


plt.suptitle('Model Prediction of Experimental Parameters', fontsize=30)
# plt.legend(loc='lower center', ncol=2, fontsize=30)
handles, labels = ax.get_legend_handles_labels()
lgd = fig.legend(handles, labels, loc='lower center', ncol=2, fontsize=20, bbox_to_anchor= (0.5, -0.07))

plt.tight_layout()
plt.savefig('Figures/greybox_trainable/GB2_ExpPar_Prediction_Model_Run_' + str(GB2_bestcase) + '.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_0.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_0.net
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_0.net
# My guess
# [ 4.99622517e+01 -8.26680395e-05  2.84548336e-01  1.20149626e+02
#   1.25455129e+03  6.61321125e-01]
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_0.net

# %%
true_pars, pred_pars, error = plot_and_metric_BandF.metric_exppar(filename, make_plots=True)

width=0.35

fig = plt.figure(figsize=(14,8))
ax = fig.add_subplot(141)
ax.bar(-width/1.8,[true_pars[0]], color='k', width=width,label='Ground Truth')
ax.bar(width/1.8,[pred_pars[0]], color='b',
        width=width, label='Model Prediction')
ax.set_xticks([0])
ax.tick_params(axis='both', labelsize=30, direction='in', length=10, width=2)
# ax.set_yscale('log')
ax.set_ylim(bottom=0.0)
ax.set_xticklabels([r"$\omega$"],fontsize=30)
plt.yticks(fontsize=30)

ax = fig.add_subplot(142)
ax.bar(-width/1.8,[true_pars[1]], color='k',width=width,label='Ground Truth')
ax.bar(width/1.8,[pred_pars[1]], color='b',
        width=width,label='Model Prediction')
ax.tick_params(axis='both', labelsize=30, direction='in', length=10, width=2)
ax.set_xticks([0])
# ax.set_yscale('log')
ax.set_ylim(bottom=0.0)
ax.set_xticklabels([r"$\sigma$"],fontsize=30)
plt.yticks(fontsize=30)

ax = fig.add_subplot(143)
ax.bar(-width/1.8,[true_pars[2]], color='k',width=width,label='Ground Truth')
ax.bar(width/1.8,[pred_pars[2]], color='b',
        width=width,label='Model Prediction')
ax.set_xticks([0])
ax.tick_params(axis='both', labelsize=30, direction='in', length=10, width=2)
# ax.set_yscale('log')
ax.set_ylim(bottom=0.0)
ax.set_xticklabels([r"$\rho$"],fontsize=30)
plt.yticks(fontsize=30)

ax = fig.add_subplot(144)
ax.bar(-width/1.8,[true_pars[3]], color='k',width=width,label='Ground Truth')
ax.bar(width/1.8,[pred_pars[3]], color='b',
        width=width,label='Model Prediction')
ax.set_xticks([0])
ax.tick_params(axis='both', labelsize=30, direction='in', length=10, width=2)
# ax.set_yscale('log')
ax.set_ylim(bottom=0.0)
ax.set_xticklabels([r"$\eta$"],fontsize=30)
plt.yticks(fontsize=30)


plt.suptitle('Model Prediction of Experimental Parameters', fontsize=30)
# plt.legend(loc='lower center', ncol=2, fontsize=30)
handles, labels = ax.get_legend_handles_labels()
lgd = fig.legend(handles, labels, loc='lower center', ncol=2, fontsize=20, bbox_to_anchor= (0.5, -0.07))

plt.tight_layout()
# plt.savefig('Figures/Prediction_of_Parameters.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# /home/smalani/PartialObservations/data/greybox_trainable/model_run_0.net
