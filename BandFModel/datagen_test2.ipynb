# %%
# %cd /home/smalani/PartialObservations
from config import config

# %cd /home/smalani/PartialObservations/BandFModel
import datagen
import numpy as np
import torch
import matplotlib.pyplot as plt
# Out:
# /home/smalani/PartialObservations
# /home/smalani/PartialObservations/BandFModel

# %%
# %cd /home/smalani/PartialObservations/BandFModel
f = np.load("../minmax/minmax.npz")

xmax = f['arr_0']
xmin = f['arr_1']
print(xmax)
print(xmin)

norm_func = lambda input: (input - xmin) / (xmax - xmin + 1e-10)

inv_norm_func = lambda input: input * (xmax - xmin + 1e-10) + xmin

# assert False
# Out:
# /home/smalani/PartialObservations/BandFModel
# [8.11282702e+01 2.24269184e-01 3.52682759e-01 2.09705578e+02
#  2.17749062e+03 8.30410222e-01]
# [1.40203080e+01 1.61528751e-05 2.78300525e-01 2.49623079e+01
#  3.85242264e+02 6.51485674e-01]

# %%
# %cd /home/smalani/PartialObservations/
data_train = datagen.generate_data(n_train=50, detail=True, duplicate_reverse=True)
# Out:
# /home/smalani/PartialObservations
#   0%|          | 0/50 [00:00<?, ?it/s]
# pakapaaakaaa detail
# (50, 6)

# %%
x_data = data_train[0]

t_in = data_train[2]
x_in = data_train[3]
p_in = data_train[4]

print(x_in.shape)
print(x_data.shape)
# Out:
# (50, 1000, 6)
# (50, 6)

# %%
# %cd /home/smalani/PartialObservations
# np.savez('minmax/initialcond',x_in)
# Out:
# /home/smalani/PartialObservations

# %%
plt.figure(figsize=(20,10))

labels = ['x', 'y', 'z', 'u', 'v', 'g']
for i in range(6):
    plt.subplot(int(str(32) + str(i+1)))
    for j in range(x_in.shape[0]):
        plt.plot(x_in[j,:,0], x_in[j,:,i])
        plt.ylabel(labels[i])
plt.xlabel('x')
plt.show()

# %%
plt.figure(figsize=(20,10))

labels = ['x', 'y', 'z', 'u', 'v', 'g']
for i in range(6):
    plt.subplot(int(str(61) + str(i+1)))
    for j in range(x_in.shape[0]):
        plt.plot(t_in[j,:], x_in[j,:,i])
        plt.ylabel(labels[i])
plt.xlabel('Time')
plt.show()

plt.figure(figsize=(20,10))

labels = ['x', 'y', 'z', 'u', 'v', 'g']
for i in range(6):
    plt.subplot(int(str(61) + str(i+1)))
    for j in range(x_in.shape[0]):
        plt.plot(t_in[j,:], norm_func(x_in)[j,:,i])
        plt.ylabel(labels[i])
plt.xlabel('Time')
plt.show()

plt.figure(figsize=(20,10))

labels = ['x', 'y', 'z', 'u', 'v', 'g']
for i in range(6):
    plt.subplot(int(str(32) + str(i+1)))
    for j in range(x_in.shape[0]):
        plt.scatter(inv_norm_func(norm_func(x_in))[j,:,i], x_in[j,:,i])
        plt.ylabel(labels[i])
plt.xlabel('Time')
plt.show()

# %%
plt.figure(figsize=(20,10))

j = 10

labels = ['x', 'y', 'z', 'u', 'v', 'g']
for i in range(6):
    plt.subplot(int(str(61) + str(i+1)))
    plt.plot(t_in[j,:], x_in[j,:,i], 'k-')
    plt.plot(x_data[j,i][1], x_data[j,i][0], 'kx')
    plt.ylabel(labels[i])
plt.xlabel('Time')
plt.show()

# j = j + 50

labels = ['x', 'y', 'z', 'u', 'v', 'g']
for i in range(6):
    plt.subplot(int(str(61) + str(i+1)))
    plt.plot(t_in[j+50,:], x_in[j+50,:,i], 'k-')
    plt.plot(x_data[j,i][1], x_data[j,i][0], 'kx')
    plt.ylabel(labels[i])
plt.xlabel('Time')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_14743/3519491144.py in <module>
#      17 for i in range(6):
#      18     plt.subplot(int(str(61) + str(i+1)))
# ---> 19     plt.plot(t_in[j+50,:], x_in[j+50,:,i], 'k-')
#      20     plt.plot(x_data[j,i][1], x_data[j,i][0], 'kx')
#      21     plt.ylabel(labels[i])
#
# IndexError: index 60 is out of bounds for axis 0 with size 50

# %%
print(x_data.shape)
print(x_data[0,0].shape)
