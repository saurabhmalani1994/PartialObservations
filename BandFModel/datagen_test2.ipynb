# %%
# %cd /home/smalani/PartialObservations
from config import config

# %cd /home/smalani/PartialObservations/BandFModel
import datagen
import numpy as np
import torch
import matplotlib.pyplot as plt
# Out:
# /home/smalani/PartialObservations
# /home/smalani/PartialObservations/BandFModel

# %%
# %cd /home/smalani/PartialObservations/BandFModel
f = np.load("../minmax/minmax.npz")

xmax = f['arr_0']
xmin = f['arr_1']
print(xmax)
print(xmin)

norm_func = lambda input: (input - xmin) / (xmax - xmin + 1e-10)

inv_norm_func = lambda input: input * (xmax - xmin + 1e-10) + xmin
# Out:
# /home/smalani/PartialObservations/BandFModel
# [8.71309395e+01 0.00000000e+00 3.67490695e-01 2.37892255e+02
#  2.31174565e+03 8.54479938e-01]
# [ 11.09503776   0.           0.26592083   5.5062973  113.23804629
#    0.60660138]

# %%
# %cd /home/smalani/PartialObservations/
data_train = datagen.generate_data(n_train=50, detail=True, duplicate_reverse=True)
# Out:
# /home/smalani/PartialObservations
#   0%|          | 0/50 [00:00<?, ?it/s]
# pakapaaakaaa detail
# (50, 6)

# %%
x_data = data_train[0]

t_in = data_train[2]
x_in = data_train[3]
p_in = data_train[4]

print(x_in.shape)
print(x_data.shape)
# Out:
# (50, 1000, 6)
# (50, 6)

# %%
# %cd /home/smalani/PartialObservations
# np.savez('minmax/initialcond',x_in)

# %%
plt.figure(figsize=(20,10))

labels = ['x', 'y', 'z', 'u', 'v', 'g']
for i in range(6):
    plt.subplot(int(str(32) + str(i+1)))
    for j in range(x_in.shape[0]):
        plt.plot(x_in[j,:,0], x_in[j,:,i])
        plt.ylabel(labels[i])
plt.xlabel('x')
plt.show()

# %%
plt.figure(figsize=(20,10))

labels = ['x', 'y', 'z', 'u', 'v', 'g']
for i in range(6):
    plt.subplot(int(str(61) + str(i+1)))
    for j in range(x_in.shape[0]):
        plt.plot(t_in[j,:], x_in[j,:,i])
        plt.ylabel(labels[i])
plt.xlabel('Time')
plt.show()

plt.figure(figsize=(20,10))

labels = ['x', 'y', 'z', 'u', 'v', 'g']
for i in range(6):
    plt.subplot(int(str(61) + str(i+1)))
    for j in range(x_in.shape[0]):
        plt.plot(t_in[j,:], norm_func(x_in)[j,:,i])
        plt.ylabel(labels[i])
plt.xlabel('Time')
plt.show()

plt.figure(figsize=(20,10))

labels = ['x', 'y', 'z', 'u', 'v', 'g']
for i in range(6):
    plt.subplot(int(str(32) + str(i+1)))
    for j in range(x_in.shape[0]):
        plt.scatter(inv_norm_func(norm_func(x_in))[j,:,i], x_in[j,:,i])
        plt.ylabel(labels[i])
plt.xlabel('Time')
plt.show()

# %%
plt.figure(figsize=(20,10))

j = 10

labels = ['x', 'y', 'z', 'u', 'v', 'g']
for i in range(6):
    plt.subplot(int(str(61) + str(i+1)))
    plt.plot(t_in[j,:], x_in[j,:,i], 'k-')
    plt.plot(x_data[j,i][1], x_data[j,i][0], 'kx')
    plt.ylabel(labels[i])
plt.xlabel('Time')
plt.show()

# j = j + 50

labels = ['x', 'y', 'z', 'u', 'v', 'g']
for i in range(6):
    plt.subplot(int(str(61) + str(i+1)))
    plt.plot(t_in[j+50,:], x_in[j+50,:,i], 'k-')
    plt.plot(x_data[j,i][1], x_data[j,i][0], 'kx')
    plt.ylabel(labels[i])
plt.xlabel('Time')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_12027/1726214090.py in <module>
#      17 for i in range(6):
#      18     plt.subplot(int(str(61) + str(i+1)))
# ---> 19     plt.plot(t_in[j,:], x_in[j,:,i], 'k-')
#      20     plt.plot(x_data[j,i][1], x_data[j,i][0], 'kx')
#      21     plt.ylabel(labels[i])
#
# IndexError: index 60 is out of bounds for axis 0 with size 50

# %%
print(x_data.shape)
print(x_data[0,0].shape)
# Out:
# (50, 6)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_12027/433345340.py in <module>
#       1 print(x_data.shape)
# ----> 2 print(x_data[0,0].shape)
#
# AttributeError: 'tuple' object has no attribute 'shape'
