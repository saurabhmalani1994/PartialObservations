# %%
# %cd /home/smalani/PartialObservations/
import matplotlib.pyplot as plt
from BandFModel import datagen
from config import config
from BandFModel import num_integrator
# Out:
# /home/smalani/PartialObservations

# %%
# %cd /home/smalani/PartialObservations/
data_train = datagen.generate_data(n_train=2, detail=True, duplicate_reverse=False, tmax=config["DATA"]["TMAX"], x_sample_num=config["DATA"]["X_SAMPLE_NUM"])

pars = datagen.par_fun(D=1/7.3, sf=2.5)

init = data_train[3][0,0,:]
dt=10
tspan = [data_train[2][0,0], data_train[2][0,-1]]
func = datagen.ode_fun

tout, xout = num_integrator.RK4_int(func, tspan, init, pars, dt)

# init = data_train[3][0,-1,:]
# dt=-0.001
# tspan = [data_train[2][0,-1], data_train[2][0,0]]
# func = datagen.ode_fun

# tout_rev, xout_rev = num_integrator.RK2_int(func, tspan, init, pars, dt)
# Out:
# /home/smalani/PartialObservations
#   0%|          | 0/2 [00:00<?, ?it/s]
# pakapaaakaaa detail
# (2, 6)

# %%
labels = ['x', 'y', 'z', 'u', 'v', 'g']
j=0



plt.figure(figsize=(20,10))

for i in range(6):
    plt.subplot(int(str(61) + str(i+1)))
    plt.plot(data_train[2][j,:], data_train[3][j,:,i], 'k-')
    plt.plot(x_data[j,i][1], x_data[j,i][0], 'kx')
    # plt.plot(x_data[j+50,i][1], x_data[j+50,i][0], 'bx')
    plt.plot(tout, xout[i,:], 'b-')
    # plt.plot(tout_rev[:], xout_rev[i,:], 'b--')
    plt.ylabel(labels[i])
plt.xlabel('Time')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13009/760107635.py in <module>
#      12     # plt.plot(x_data[j+50,i][1], x_data[j+50,i][0], 'bx')
#      13     # plt.plot(tout, xout[i,:], 'b-')
# ---> 14     plt.plot(tout_rev[:], xout_rev[i,:], 'b--')
#      15     plt.ylabel(labels[i])
#      16 plt.xlabel('Time')
#
# ~/.conda/envs/torch-env/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/.conda/envs/torch-env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/.conda/envs/torch-env/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~/.conda/envs/torch-env/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (0,) and (1,)
