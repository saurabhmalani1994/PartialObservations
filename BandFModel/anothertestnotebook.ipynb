# %%
from PartialObservations.BandFModel import datagen

# %%
sol = datagen.testme()
# Out:
# (0.201450443190975, 250.0, 9.7, 10.0, 0.1313868613138686, 1.2916666666666667, 0.29411764705882354, 0.3676470588235294, 0.3676470588235294, 0.11764705882352941, 0.16176470588235292)

# %%
# output, theta_output, output_detail_t, output_detail, output_detail_theta = datagen.generate_data(detail=True)
# Out:
# Error: Session cannot generate requests
# at S.executeCodeCell (/home/smalani/.vscode-server/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:301742)
# at S.execute (/home/smalani/.vscode-server/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:300732)
# at S.start (/home/smalani/.vscode-server/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:296408)
# at async t.CellExecutionQueue.executeQueuedCells (/home/smalani/.vscode-server/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:312326)
# at async t.CellExecutionQueue.start (/home/smalani/.vscode-server/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:311862)

# %%
# y0 = [4.34848022e+01, 1.06526482e-11, 2.83355578e-01, 1.37417997e+02,
#  1.08694220e+03, 6.59167691e-01]

# sol = datagen.integrate_cstr(tmin=0, tmax=10, y0=y0, verbose=False, theta=7.3, sf=2.5, teval=None)
# Out:
# (0.201450443190975, 250.0, 9.7, 10.0, 0.1313868613138686, 1.2916666666666667, 0.29411764705882354, 0.3676470588235294, 0.3676470588235294, 0.11764705882352941, 0.16176470588235292)
