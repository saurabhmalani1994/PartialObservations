# %%
from config import config
import datagen
import matplotlib.pyplot as plt

# %%
Da, a, t_detail, a_detail = datagen.generate_data(detail=True)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
index = 3

print(a.shape)
print(a[index,0][0].shape)
print(a[index,0][1].shape)
print(a[index,0])

plt.figure()
plt.plot(a[index,0][1], a[index,0][0], 'x', color='blue')
plt.plot(t_detail[index,:], a_detail[index,0,:], color='black')
plt.xlabel(r'x_1')
plt.title('Da: ' + str(Da[index]))

plt.figure()
plt.plot(a[index,1][1], a[index,1][0], 'x', color='blue')
plt.plot(t_detail[index,:], a_detail[index,1,:], color='black')
plt.xlabel(r'x_2')
plt.title('Da: ' + str(Da[index]))
# Out:
# (11, 2)
# (13,)
# (13,)
# (array([0.48260766, 0.43595746, 0.41170485, 0.40831181, 0.41820741,
#        0.43255651, 0.44378868, 0.44793253, 0.44563257, 0.44039553,
#        0.43570233, 0.43335895, 0.43343558]), array([0.     , 0.50001, 1.00001, 1.50005, 2.00024, 2.50024, 3.00028,
#        3.50046, 4.00042, 4.50049, 5.00043, 5.50037, 6.00064]))
# Text(0.5, 1.0, 'Da: 0.23333333333333334')
