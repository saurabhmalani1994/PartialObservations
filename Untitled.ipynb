# %%
from config import config
import datagen
import matplotlib.pyplot as plt

# %%
Da, a, t_detail, a_detail = datagen.generate_data(detail=True)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
index = 0

print(a.shape)
print(a[index,0])
print(a_detail.shape)
plt.plot(a[index,0][1], a[index,0][0], 'x', color='blue')
plt.plot(t_detail[index,:], a_detail[index,0,:], color='black')
plt.title('Da: ' + str(Da[index]))
# Out:
# (11, 2)
# (array([0.74835221, 0.76865037, 0.85547455, 0.78859518, 0.82806907,
#        0.83858734, 0.8391412 , 0.84092911, 0.83024702, 0.79819398,
#        0.79389899, 0.80681041]), array([0.44474, 2.11354, 2.81416, 3.59414, 4.36816, 4.50981, 4.52202,
#        4.58012, 4.89134, 5.33468, 5.45144, 5.90936]))
# (11, 2, 1000)
# Text(0.5, 1.0, 'Da: 0.4666666666666667')
