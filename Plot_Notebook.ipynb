# %%
from utils import config
import make_plots

make_plots.main(config)
# Out:
# 0.970066361435889
# 0.308382989458118
# 4.698541570032756
# 0.49404454122801383
#   0%|          | 0/1 [00:00<?, ?it/s]
# /home/smalani/PartialObservations/utils.py:65: RuntimeWarning: overflow encountered in exp
#   dx1dt = -x1 + Da * (1-x1) * np.exp(x2)
# /home/smalani/PartialObservations/utils.py:66: RuntimeWarning: overflow encountered in exp
#   dx2dt = -x2 + B * Da * (1-x1) * np.exp(x2) - beta * x2
# /home/smalani/PartialObservations/utils.py:65: RuntimeWarning: invalid value encountered in double_scalars
#   dx1dt = -x1 + Da * (1-x1) * np.exp(x2)
# /home/smalani/PartialObservations/utils.py:66: RuntimeWarning: invalid value encountered in double_scalars
#   dx2dt = -x2 + B * Da * (1-x1) * np.exp(x2) - beta * x2
# Using dt of 0.050000000000000044
# data/model__hidden_layers_1_64.net
# Network(
#   (sigmoid): Sigmoid()
#   (model): Sequential(
#     (0): Linear(in_features=3, out_features=32, bias=True)
#     (1): Snake()
# ...
