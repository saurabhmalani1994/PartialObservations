# %%
from config import config
from URPModel import make_plots

make_plots.main(config)
# Out:
# 0.9076345562934875
# 0.30876263976097107
# 3.5092878341674805
# 0.5580481886863708
# [0.92693592 3.8922446 ]
# [0.30844671 0.55569286]
# data/model_.net
# my_Network(
#   (net): MLP(
#     (layers): ModuleList(
#       (0): Linear(in_features=3, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#     )
#     (activation): SiLU()
#     (output_layer): Linear(in_features=64, out_features=1, bias=True)
#   )
# )
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5b7102bac5f5> in <module>
#       2 from URPModel import make_plots
#       3
# ----> 4 make_plots.main(config)
#
# ~/PartialObservations/URPModel/make_plots.py in main(config, Da)
#      55 #     Da_list = [0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4, 0.4]
#      56
# ---> 57     helper.make_transients(Da_list)
# ...
