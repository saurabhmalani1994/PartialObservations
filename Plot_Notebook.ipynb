# %%
from utils import config
import make_plots

make_plots.main(config)
# Out:
# 0.9076345562934875
# 0.30876263976097107
# 3.5092878341674805
# 0.5580481886863708
# [0.9571471  3.62116473]
# [0.30863066 0.55804819]
# data/model_.net
# my_Network(
#   (net): MLP(
#     (layers): ModuleList(
#       (0): Linear(in_features=3, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#     )
#     (activation): SiLU()
#     (output_layer): Linear(in_features=64, out_features=1, bias=True)
#   )
# )
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# [0.9571471  3.62116473]
# [0.30863066 0.55804819]
# data/model_.net
# my_Network(
#   (net): MLP(
#     (layers): ModuleList(
#       (0): Linear(in_features=3, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#     )
#     (activation): SiLU()
#     (output_layer): Linear(in_features=64, out_features=1, bias=True)
#   )
# )
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# [0.9571471  3.62116473]
# [0.30863066 0.55804819]
# data/model_.net
# my_Network(
# ...
