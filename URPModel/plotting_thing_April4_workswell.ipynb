# %%
# %cd /home/smalani/PartialObservations_URP2

from URPModel import make_plots, helper, URP_metrics
from config import config
import numpy as np
# Out:
# /home/smalani/PartialObservations_URP2

# %%
import numpy as np
from config import config

Cases = ["Case1", "Case2a", "Case2b", "Case3", "Case4", "Case5", "Case6","Case8a", "Case8b"]
# Cases = ["Case1"]

minindex = []
for j in range(len(Cases)):
    # Case = "Case8a"
    Case = Cases[j]
    if Case == "Case8a":
        config["MODEL"]["BOX"] = 'Grey'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 77
    elif Case == "Case8b":
        config["MODEL"]["BOX"] = 'Grey'
        config["MODEL"]["Parameters"] = 'Trainable'
        config["DATA"]["N_TRAIN"] = 77
    elif Case == "Case1":
        config["MODEL"]["BOX"] = 'Black'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 17
    else:
        config["MODEL"]["BOX"] = 'Black'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 77

    print('======================================')
    print('======================================')

    L1_norm_arr, L2_norm_arr, Linf_norm_arr = [], [] , []
    for index in range(10):
        filename = "/home/smalani/PartialObservations_URP2/data/" + Case + "/model_run_" + str(index) + ".net"
        real_RHS_x1, real_RHS_x2, pred_RHS_x1, pred_RHS_x2, L1_norm, L2_norm, Linf_norm = URP_metrics.metric_RHS(filename=filename, make_plots=False)
        L1_norm_arr.append(L1_norm)
        L2_norm_arr.append(L2_norm)
        Linf_norm_arr.append(Linf_norm)

    # minindex.append(np.argmin(L2_norm_arr))
    print(Case + " RHS error")
    print("L1 norm: mean", np.mean(L1_norm_arr))
    print("L1 norm: std", np.std(L1_norm_arr))
    print("L2 norm: mean", np.mean(L2_norm_arr))
    print("L2 norm: std", np.std(L2_norm_arr))
    print("Linf norm: mean", np.mean(Linf_norm_arr))
    print("Linf norm: std", np.std(Linf_norm_arr))

    L1_norm_arr, L2_norm_arr, Linf_norm_arr = [], [] , []
    for index in range(10):
        filename = "/home/smalani/PartialObservations_URP2/data/" + Case + "/model_run_" + str(index) + ".net"
        RHS_hair_error_trueLC_True, RHS_hair_error_trueLC_Pred, L1_norm, L2_norm, Linf_norm = URP_metrics.metric_hairFromTrue(filename=filename, make_plots=False)
        L1_norm_arr.append(L1_norm)
        L2_norm_arr.append(L2_norm)
        Linf_norm_arr.append(Linf_norm)

    minindex.append(np.argmin(L2_norm_arr))
    print(Case + " Solution error")
    print("L1 norm: mean", np.mean(L1_norm_arr))
    print("L1 norm: std", np.std(L1_norm_arr))
    print("L2 norm: mean", np.mean(L2_norm_arr))
    print("L2 norm: std", np.std(L2_norm_arr))
    print("Linf norm: mean", np.mean(Linf_norm_arr))
    print("Linf norm: std", np.std(Linf_norm_arr))

print(minindex)
# Out:
# ======================================
# ======================================
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_9.net
# Case1 RHS error
# L1 norm: mean 0.0036603333672896214
# L1 norm: std 0.0005172548293683233
# L2 norm: mean 0.0027167967859426283
# L2 norm: std 0.00036348926316499884
# Linf norm: mean 0.0045641091467466
# Linf norm: std 0.0005710454088998989
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_9.net
# Case1 Solution error
# L1 norm: mean 0.013118894044148571
# L1 norm: std 0.002350288490455576
# L2 norm: mean 0.009679299998630871
# L2 norm: std 0.001711626833038434
# Linf norm: mean 0.01583493768451594
# Linf norm: std 0.002734993889674246
# ======================================
# ======================================
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_9.net
# Case2a RHS error
# L1 norm: mean 0.01318107012603921
# L1 norm: std 0.000976685386271149
# L2 norm: mean 0.009710749948175825
# L2 norm: std 0.0007553529321606138
# Linf norm: mean 0.016084767521173306
# Linf norm: std 0.001342160673283474
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_9.net
# Case2a Solution error
# L1 norm: mean 0.019703026636557795
# L1 norm: std 0.001679873790189386
# L2 norm: mean 0.014861647569495184
# L2 norm: std 0.0011970667756096263
# Linf norm: mean 0.02576652430791675
# Linf norm: std 0.0022207186665705327
# ======================================
# ======================================
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_9.net
# Case2b RHS error
# L1 norm: mean 0.007895541811652826
# L1 norm: std 0.001639281532553342
# L2 norm: mean 0.0059509638337753145
# L2 norm: std 0.0012054848484414416
# Linf norm: mean 0.010333170214845897
# Linf norm: std 0.002078456554146668
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_9.net
# Case2b Solution error
# L1 norm: mean 0.011415764943448032
# L1 norm: std 0.0014740606052207543
# L2 norm: mean 0.008692976300754133
# L2 norm: std 0.0011839138213301653
# Linf norm: mean 0.015005366431604744
# Linf norm: std 0.002375920594891751
# ======================================
# ======================================
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_9.net
# Case3 RHS error
# L1 norm: mean 0.004672184057446023
# L1 norm: std 0.00044404847631668363
# L2 norm: mean 0.0034952221204834094
# L2 norm: std 0.0003368088543934806
# Linf norm: mean 0.005971089709000512
# Linf norm: std 0.0006208484441270586
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_9.net
# Case3 Solution error
# L1 norm: mean 0.005561049729045656
# L1 norm: std 0.0005995935558024057
# L2 norm: mean 0.0042258951537102836
# L2 norm: std 0.0004309972919139392
# Linf norm: mean 0.007440414620048847
# Linf norm: std 0.0008027265289210118
# ======================================
# ======================================
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_9.net
# Case4 RHS error
# L1 norm: mean 0.0049051694556483255
# L1 norm: std 0.0006271857988615584
# L2 norm: mean 0.003662512502595317
# L2 norm: std 0.0004568622045085859
# Linf norm: mean 0.006271894340011248
# Linf norm: std 0.0007547214454317125
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_9.net
# Case4 Solution error
# L1 norm: mean 0.008080043509278559
# L1 norm: std 0.0007873396502240984
# L2 norm: mean 0.006093716186421025
# L2 norm: std 0.000562504369335938
# Linf norm: mean 0.010387684100512122
# Linf norm: std 0.0009427104815703559
# ======================================
# ======================================
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_9.net
# Case5 RHS error
# L1 norm: mean 0.00922191727186494
# L1 norm: std 0.001051035922461097
# L2 norm: mean 0.007115704023112908
# L2 norm: std 0.000814443430998774
# Linf norm: mean 0.012671087372706844
# Linf norm: std 0.001497614233119293
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_9.net
# Case5 Solution error
# L1 norm: mean 0.011624945460562445
# L1 norm: std 0.002210027108235293
# L2 norm: mean 0.0089135634782748
# L2 norm: std 0.0016540850292580274
# Linf norm: mean 0.015876218567643676
# Linf norm: std 0.002976978943808815
# ======================================
# ======================================
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_9.net
# Case6 RHS error
# L1 norm: mean 0.009985369642266278
# L1 norm: std 0.0014061808351495942
# L2 norm: mean 0.007692628730997691
# L2 norm: std 0.0010503178264129492
# Linf norm: mean 0.013669846618322634
# Linf norm: std 0.0018003226679685646
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_9.net
# Case6 Solution error
# L1 norm: mean 0.009913734195602477
# L1 norm: std 0.001717439312935497
# L2 norm: mean 0.007917271334310203
# L2 norm: std 0.001357663515721241
# Linf norm: mean 0.014527589927379913
# Linf norm: std 0.002560610266497027
# ======================================
# ======================================
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_9.net
# Case8a RHS error
# L1 norm: mean 0.006236697138120582
# L1 norm: std 0.0007241201085584265
# L2 norm: mean 0.004432340884140715
# L2 norm: std 0.0005146228991262383
# Linf norm: mean 0.0068651080178872715
# Linf norm: std 0.0007970825988635239
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_9.net
# Case8a Solution error
# L1 norm: mean 0.01366054557589278
# L1 norm: std 0.0017974916826049123
# L2 norm: mean 0.00990641247377184
# L2 norm: std 0.0012648990938271655
# Linf norm: mean 0.015263001320134856
# Linf norm: std 0.0017775235333782702
# ======================================
# ======================================
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_9.net
# Case8b RHS error
# L1 norm: mean 0.008969396907185628
# L1 norm: std 0.0028730871404763483
# L2 norm: mean 0.006488142244552313
# L2 norm: std 0.002078413361105994
# Linf norm: mean 0.010350156683095016
# Linf norm: std 0.0034101876459148276
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_9.net
# Case8b Solution error
# L1 norm: mean 0.0167748809613708
# L1 norm: std 0.0023810086726436617
# L2 norm: mean 0.012223441927659586
# L2 norm: std 0.0017277144296220656
# Linf norm: mean 0.019037095083758847
# Linf norm: std 0.002565210840626983
# [2, 0, 2, 5, 8, 2, 7, 2, 0]

# %%
# %cd /home/smalani/PartialObservations_URP2

from URPModel import make_plots, helper, URP_metrics
from config import config
import numpy as np

import numpy as np
from config import config

Cases = ["Case1", "Case2a", "Case2b", "Case3", "Case4", "Case5", "Case6","Case8a", "Case8b"]

Cases = ["Case8a", "Case8b"]
for Case in Cases:
    if Case == "Case8a":
        config["MODEL"]["BOX"] = 'Grey'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 77
    elif Case == "Case8b":
        config["MODEL"]["BOX"] = 'Grey'
        config["MODEL"]["Parameters"] = 'Trainable'
        config["DATA"]["N_TRAIN"] = 77
    elif Case == "Case1":
        config["MODEL"]["BOX"] = 'Black'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 17
    else:
        config["MODEL"]["BOX"] = 'Black'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 77

    print('======================================')
    print('======================================')

    L1_norm_arr, L2_norm_arr, Linf_norm_arr = [], [] , []
    for index in range(10):
        filename = "/home/smalani/PartialObservations_URP2/data/" + Case + "/model_run_" + str(index) + ".net"
        real_phi, pred_phi, L1_norm, L2_norm, Linf_norm = URP_metrics.metric_Phi(filename=filename, make_plots=False)
        L1_norm_arr.append(L1_norm)
        L2_norm_arr.append(L2_norm)
        Linf_norm_arr.append(Linf_norm)

    # minindex.append(np.argmin(L2_norm_arr))
    print(Case + " Phi error")
    print("L1 norm: mean", np.mean(L1_norm_arr))
    print("L1 norm: std", np.std(L1_norm_arr))
    print("L2 norm: mean", np.mean(L2_norm_arr))
    print("L2 norm: std", np.std(L2_norm_arr))
    print("Linf norm: mean", np.mean(Linf_norm_arr))
    print("Linf norm: std", np.std(Linf_norm_arr))
# Out:
# /home/smalani/PartialObservations_URP2
# ======================================
# ======================================
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_9.net
# Case8a Phi error
# L1 norm: mean 0.005305767685931325
# L1 norm: std 0.0006160332925642375
# L2 norm: mean 0.005305767685931325
# L2 norm: std 0.0006160332925642375
# Linf norm: mean 53.05767685931325
# Linf norm: std 6.160332925642375
# ======================================
# ======================================
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_9.net
# Case8b Phi error
# L1 norm: mean 0.007772409595242906
# L1 norm: std 0.00225427691102101
# L2 norm: mean 0.007772409595242906
# L2 norm: std 0.00225427691102101
# Linf norm: mean 77.72409595242905
# Linf norm: std 22.5427691102101

# %%
print(real_phi.shape)
# Out:
# (10000, 1)

# %%
# %cd /home/smalani/PartialObservations_URP2

from URPModel import make_plots, helper, URP_metrics
from config import config
import numpy as np

import numpy as np
from config import config

Cases = ["Case1", "Case2a", "Case2b", "Case3", "Case4", "Case5", "Case6","Case8a", "Case8b"]

Cases = ["Case8b"]
for Case in Cases:
    if Case == "Case8a":
        config["MODEL"]["BOX"] = 'Grey'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 77
    elif Case == "Case8b":
        config["MODEL"]["BOX"] = 'Grey'
        config["MODEL"]["Parameters"] = 'Trainable'
        config["DATA"]["N_TRAIN"] = 77
    elif Case == "Case1":
        config["MODEL"]["BOX"] = 'Black'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 17
    else:
        config["MODEL"]["BOX"] = 'Black'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 77

    print('======================================')
    print('======================================')

    error_arr = []
    # L1_norm_arr, L2_norm_arr, Linf_norm_arr = [], [] , []
    for index in range(10):
        filename = "/home/smalani/PartialObservations_URP2/data/" + Case + "/model_run_" + str(index) + ".net"
        B_true, B_pred, beta_true, beta_pred, error = URP_metrics.metric_ExpPar(filename=filename, make_plots=False)
        error_arr.append(error)
        # L2_norm_arr.append(L2_norm)
        # Linf_norm_arr.append(Linf_norm)

    # minindex.append(np.argmin(L2_norm_arr))
    print(Case + " ExpPar error")
    print("Error: mean", np.mean(error_arr))
    print("Error: std", np.std(error_arr))
    # print("L2 norm: mean", np.mean(L2_norm_arr))
    # print("L2 norm: std", np.std(L2_norm_arr))
    # print("Linf norm: mean", np.mean(Linf_norm_arr))
    # print("Linf norm: std", np.std(Linf_norm_arr))
# Out:
# /home/smalani/PartialObservations_URP2
# ======================================
# ======================================
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_1.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_3.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_4.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_6.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_9.net
# Case8b ExpPar error
# Error: mean 0.04445913795268897
# Error: std 0.022813206570456858

# %%
# minindex = [2, 0, 0, 5, 8, 2, 7, 2, 0]
# minindex = [2, 0, 2, 5, 8, 2, 7, 2, 0]

# %%
import matplotlib.pyplot as plt



unstable_ss, unstable_Da, stable_ss1, stable_Da1, stable_ss2, stable_Da2, Da_arr, x1min, x2min, x1max, x2max, period, period_point = \
    URP_metrics.make_Bifurc_true()

# %%
# print(unstable_Da_pred)

# %%
from config import config

Cases = ["Case1", "Case2a", "Case2b", "Case3", "Case4", "Case5", "Case6","Case8a", "Case8b"]

for i in range(len(Cases)):
    Case = Cases[i]
    Case_Best_Index = minindex[i]

    if Case == "Case8a":
        config["MODEL"]["BOX"] = 'Grey'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 77
    elif Case == "Case8b":
        config["MODEL"]["BOX"] = 'Grey'
        config["MODEL"]["Parameters"] = 'Trainable'
        config["DATA"]["N_TRAIN"] = 77
    elif Case == "Case1":
        config["MODEL"]["BOX"] = 'Black'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 17
    else:
        config["MODEL"]["BOX"] = 'Black'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 77

    # Case = "Case1"
    # config["MODEL"]["BOX"] = 'Black'
    # config["MODEL"]["Parameters"] = 'Fixed'
    # config["DATA"]["N_TRAIN"] = 17

    # index = 0
    filename = "/home/smalani/PartialObservations_URP2/data/" + Case + "/model_run_" + str(Case_Best_Index) + ".net"
    unstable_ss_pred, unstable_Da_pred, stable_ss_pred, stable_Da_pred, Da_arr_pred, x1min_pred, x2min_pred, x1max_pred, x2max_pred = \
        URP_metrics.make_Bifurc_prediction(filename=filename)

    fig = plt.figure(figsize=(15,6))
    ax = fig.add_subplot(121)
    ax.plot(unstable_Da, unstable_ss[:,0], 'k--', lw=2)
    ax.plot(Da_arr, x1min, 'k', lw=2)
    ax.plot(Da_arr, x1max, 'k', lw=2)

    ax.plot(unstable_Da_pred, unstable_ss_pred[:,0], 'b--', lw=2)
    ax.plot(Da_arr_pred, x1min_pred, 'b', lw=2)
    ax.plot(Da_arr_pred, x1max_pred, 'b', lw=2)
    ax.tick_params(axis='both', which='major', labelsize=20, direction='in', length=10, width=2)
    ax.set_ylabel('$x_1$', fontsize=30)
    ax.set_xlabel('Da', fontsize=30)
    [x.set_linewidth(1.5) for x in ax.spines.values()]

    ax = fig.add_subplot(122)
    ax.plot(unstable_Da, unstable_ss[:,1], 'k--', lw=2)
    ax.plot(Da_arr, x2min, 'k', lw=2)
    ax.plot(Da_arr, x2max, 'k', lw=2, label='True')
    ax.plot(unstable_Da_pred, unstable_ss_pred[:,1], 'b--', lw=2)
    ax.plot(Da_arr_pred, x2min_pred, 'b', lw=2)
    ax.plot(Da_arr_pred, x2max_pred, 'b', lw=2, label='Predicted')
    ax.set_ylabel('$x_2$', fontsize=30)
    ax.set_xlabel('Da', fontsize=30)
    ax.tick_params(axis='both', which='major', labelsize=20, direction='in', length=10, width=2)
    [x.set_linewidth(1.5) for x in ax.spines.values()]
    fig.savefig("/home/smalani/PartialObservations_URP2/Figures/" + Case + "/" + "Model_run_" + \
                str(Case_Best_Index) + "_BifurcationDiagram" + ".png")
    fig.legend(loc='lower center', bbox_to_anchor=(0.5, -0.10), ncol=2, fontsize=20)
# Out:
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_0.net

# %%
minindex = [2, 0, 2, 5, 8, 2, 7, 2, 0]

# %%
# %cd /home/smalani/PartialObservations_URP2

from URPModel import make_plots, helper, URP_metrics
from config import config
import numpy as np

import numpy as np
from config import config

Cases = ["Case1", "Case2a", "Case2b", "Case3", "Case4", "Case5", "Case6","Case8a", "Case8b"]

for i in range(len(Cases)):

# i = 8
# Case_Best_Index = 0

    Case = Cases[i]
    Case_Best_Index = minindex[i]

    if Case == "Case8a":
        config["MODEL"]["BOX"] = 'Grey'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 77
    elif Case == "Case8b":
        config["MODEL"]["BOX"] = 'Grey'
        config["MODEL"]["Parameters"] = 'Trainable'
        config["DATA"]["N_TRAIN"] = 77
    elif Case == "Case1":
        config["MODEL"]["BOX"] = 'Black'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 17
    else:
        config["MODEL"]["BOX"] = 'Black'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 77

    filename = "/home/smalani/PartialObservations_URP2/data/" + Case + "/model_run_" + str(Case_Best_Index) + ".net"
    real_RHS_x1, real_RHS_x2, pred_RHS_x1, pred_RHS_x2, L1_norm, L2_norm, Linf_norm = \
        URP_metrics.metric_RHS(filename=filename)

    import matplotlib.pyplot as plt

    fig = plt.figure(figsize=(15,6))
    ax = fig.add_subplot(121)
    ax.scatter(real_RHS_x1, pred_RHS_x1, color='b', s=4)
    ax.plot([min(real_RHS_x1), max(real_RHS_x1)], [min(real_RHS_x1), max(real_RHS_x1)], 'k-', lw=2)
    ax.tick_params(axis='both', which='major', labelsize=20, direction='in', length=10, width=2)
    ax.set_title('$x_1$', fontsize=30)
    # ax.set_ylabel('$x_1$', fontsize=30)
    # ax.set_xlabel('Da', fontsize=30)
    [x.set_linewidth(1.5) for x in ax.spines.values()]

    ax = fig.add_subplot(122)
    ax.scatter(real_RHS_x2, pred_RHS_x2, color='b', s=4)
    ax.plot([min(real_RHS_x2), max(real_RHS_x2)], [min(real_RHS_x2), max(real_RHS_x2)], 'k-', lw=2)
    # ax.set_ylabel('$x_2$', fontsize=30)
    # ax.set_xlabel('Da', fontsize=30)
    ax.set_title('$x_2$', fontsize=30)
    ax.tick_params(axis='both', which='major', labelsize=20, direction='in', length=10, width=2)
    [x.set_linewidth(1.5) for x in ax.spines.values()]
    fig.supxlabel('True RHS', fontsize=30)
    fig.supylabel('Predicted RHS', fontsize=30)
    fig.savefig("/home/smalani/PartialObservations_URP2/Figures/" + Case + "/" + "Model_run_" + \
                str(Case_Best_Index) + "_RHSPlot" + ".png")


    # fig.legend(loc='lower center', bbox_to_anchor=(0.5, -0.10), ncol=2, fontsize=20)
# Out:
# /home/smalani/PartialObservations_URP2
# /home/smalani/PartialObservations_URP2/data/Case1/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case2a/model_run_0.net
# /home/smalani/PartialObservations_URP2/data/Case2b/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case3/model_run_5.net
# /home/smalani/PartialObservations_URP2/data/Case4/model_run_8.net
# /home/smalani/PartialObservations_URP2/data/Case5/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case6/model_run_7.net
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_0.net

# %%
# %cd /home/smalani/PartialObservations_URP2

from URPModel import make_plots, helper, URP_metrics
from config import config
import numpy as np

import numpy as np
from config import config

Cases = ["Case1", "Case2a", "Case2b", "Case3", "Case4", "Case5", "Case6","Case8a", "Case8b"]

for i in range(len(Cases)):

# i = 8
# Case_Best_Index = 0

    Case = Cases[i]
    Case_Best_Index = minindex[i]

    if Case == "Case8a":
        config["MODEL"]["BOX"] = 'Grey'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 77
    elif Case == "Case8b":
        config["MODEL"]["BOX"] = 'Grey'
        config["MODEL"]["Parameters"] = 'Trainable'
        config["DATA"]["N_TRAIN"] = 77
    elif Case == "Case1":
        config["MODEL"]["BOX"] = 'Black'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 17
    else:
        config["MODEL"]["BOX"] = 'Black'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 77

    if Case == "Case8a" or Case == "Case8b":

        filename = "/home/smalani/PartialObservations_URP2/data/" + Case + "/model_run_" + str(Case_Best_Index) + ".net"
        real_Phi, pred_Phi, L1_norm, L2_norm, Linf_norm = \
            URP_metrics.metric_Phi(filename=filename)

        import matplotlib.pyplot as plt

        fig = plt.figure(figsize=(8,6))
        ax = fig.add_subplot(111)
        ax.scatter(real_Phi, pred_Phi, color='b', s=4)
        ax.plot([min(real_Phi), max(real_Phi)], [min(real_Phi), max(real_Phi)], 'k-', lw=2)
        ax.tick_params(axis='both', which='major', labelsize=20, direction='in', length=10, width=2)
        ax.set_xlabel('True $\phi$', fontsize=30)
        ax.set_ylabel('Predicted $\phi$', fontsize=30)
        [x.set_linewidth(1.5) for x in ax.spines.values()]


        fig.savefig("/home/smalani/PartialObservations_URP2/Figures/" + Case + "/" + "Model_run_" + \
                    str(Case_Best_Index) + "_PhiPlot" + ".png")
# Out:
# /home/smalani/PartialObservations_URP2
# /home/smalani/PartialObservations_URP2/data/Case8a/model_run_2.net
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_0.net

# %%
# %cd /home/smalani/PartialObservations_URP2

from URPModel import make_plots, helper, URP_metrics
from config import config
import numpy as np

import numpy as np
from config import config
import matplotlib.pyplot as plt

Cases = ["Case1", "Case2a", "Case2b", "Case3", "Case4", "Case5", "Case6","Case8a", "Case8b"]

for i in range(len(Cases)):

# i = 8
    # Case_Best_Index = 0
    Case = Cases[i]
    Case_Best_Index = minindex[i]

    if Case == "Case8a":
        config["MODEL"]["BOX"] = 'Grey'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 77
    elif Case == "Case8b":
        config["MODEL"]["BOX"] = 'Grey'
        config["MODEL"]["Parameters"] = 'Trainable'
        config["DATA"]["N_TRAIN"] = 77
    elif Case == "Case1":
        config["MODEL"]["BOX"] = 'Black'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 17
    else:
        config["MODEL"]["BOX"] = 'Black'
        config["MODEL"]["Parameters"] = 'Fixed'
        config["DATA"]["N_TRAIN"] = 77

    if Case == 'Case8b':
        filename = "/home/smalani/PartialObservations_URP2/data/" + Case + "/model_run_" + str(Case_Best_Index) + ".net"
        B_true, B_pred, beta_true, beta_pred, error = \
            URP_metrics.metric_ExpPar(filename=filename)

        labels = [r'$B$',r'$\beta$']
        x = np.arange(len(labels))
        width = 0.35

        fig = plt.figure(figsize=(8,6))
        ax = fig.add_subplot(111)
        ax.bar(x-width/1.8,[B_true, beta_true],width=width,label='Ground Truth', color='k')
        ax.bar(x+width/1.8,[B_pred, beta_pred],
                width=width,label='Model Prediction', color='b')
        ax.set_xticks(x)
        ax.set_xticklabels(labels,fontsize=30)
        plt.yticks(fontsize=30)
        plt.title('Prediction of Experimental Parameters',fontsize=25)
        # plt.legend(fontsize=30)

        fig.legend(loc='lower center', bbox_to_anchor=(0.5, -0.10), ncol=2, fontsize=20)
        fig.savefig("/home/smalani/PartialObservations_URP2/Figures/" + Case + "/" + "Model_run_" + \
                    str(Case_Best_Index) + "_ExpParPlot" + ".png")
# Out:
# /home/smalani/PartialObservations_URP2
# /home/smalani/PartialObservations_URP2/data/Case8b/model_run_0.net
