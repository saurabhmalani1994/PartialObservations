# %%
from config import config

import train_model


train_model.main(config)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# maxmins
# [0.91029138 3.43571548]
# [0.3089981  0.55569286]
# my_Network(
#   (net): MLP(
#     (layers): ModuleList(
#       (0): Linear(in_features=3, out_features=64, bias=True)
#       (1): Linear(in_features=64, out_features=64, bias=True)
#     )
#     (activation): SiLU()
#     (output_layer): Linear(in_features=64, out_features=1, bias=True)
#   )
# )
# Using: cuda
# Trainable parameters: 4501
# MY LEARNING RATE IS 0.01
# Train/Loss: 0.00e+00  Val/Loss: 0.00e+00:   0%|          | 0/4000 [00:00<?, ?it/s]
# Exception ignored in: <function _releaseLock at 0x2b8d198354c0>
# Traceback (most recent call last):
#   File "/home/smalani/.conda/envs/torch-env/lib/python3.8/logging/__init__.py", line 227, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f6718890bc2f> in <module>
#       4
#       5
# ----> 6 train_model.main(config)
#
# ~/PartialObservations/train_model.py in main(config)
#     151
#     152     for epoch in progress_bar:
# --> 153         train_loss = model.train(epoch)
#     154         val_loss = model.validate(epoch)
#     155         train_loss_list.append(train_loss)
#
# ~/PartialObservations/main/utils.py in train(self, epoch)
#     307             x_in = x[0][:,:-1,:]
#     308
# --> 309             xout_hat = self.net(x_in.to(self.device), p[0].to(self.device), t[0].to(self.device), index)
#     310
#     311             # Normalize vectors before loss calculation
#
# ~/.conda/envs/torch-env/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1062         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1063                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1064             return forward_call(*input, **kwargs)
#    1065         # Do not call functions when jit is used
#    1066         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/PartialObservations/main/utils.py in forward(self, x, par, time, index)
#     132             else: ind = 0
#     133
# --> 134             out = self.integrator(x_input, p_input, dt_input)
#     135             x_out.append(out)
#     136
#
# ~/PartialObservations/main/utils.py in RK4(self, x, par, dt)
#     192
#     193         ANN_input = x + k3 * dt
# --> 194         k4 = self.output(ANN_input, par)
#     195 #         k4 = torch.clip(k4, min = 0, max = 1e4)
#     196
#
# ~/PartialObservations/train_model.py in output(self, x, par)
#      87                 def output(self, x, par):
#      88
# ---> 89                     ANN_input = torch.cat((self.norm_func(x), par), dim=-1)
#      90                     g = self.net(ANN_input)[...,0]
#      91
#
# ~/PartialObservations/main/utils.py in <lambda>(input)
#      77         self.additional_pars = nn.Parameter(torch.zeros(add_par_num).to(self.device) + 0.5, requires_grad = True)
#      78
# ---> 79         self.norm_func = lambda input: norm_func(input, self.device)
#      80         self.inv_norm_func = lambda input: inv_norm_func(input, self.device)
#      81
#
# ~/PartialObservations/train_model.py in <lambda>(input, device)
#      44     print(xmin)
#      45
# ---> 46     norm_func = lambda input, device: (input - torch.tensor(xmin).float().to(device)) / \
#      47                             torch.tensor((xmax - xmin)).float().to(device)
#      48     inv_norm_func = lambda input, device: input * torch.tensor((xmax - xmin)).float().to(device) \
#
# KeyboardInterrupt:

# %%
# from utils import CSTRDataset, config
# from torch.utils.data import DataLoader

# dataset_train = CSTRDataset(config["DATA"]["N_TRAIN"], config["DATA"]["TMAX"],
#                             config["DATA"]["L_TRAJECTORIES"], 
#                        Da=config["PAR"]["Da"],
#                        B=config["PAR"]["B"],
#                        beta=config["PAR"]["beta"])
# dataset_val = CSTRDataset(config["DATA"]["N_VAL"], config["DATA"]["TMAX"],
#                           config["DATA"]["L_TRAJECTORIES"], 
#                        Da=config["PAR"]["Da"],
#                        B=config["PAR"]["B"],
#                        beta=config["PAR"]["beta"], random=True)
# dataset_test = CSTRDataset(config["DATA"]["N_TEST"], config["DATA"]["TMAX"],
#                        config["DATA"]["L_TRAJECTORIES"], 
#                        Da=config["PAR"]["Da"],
#                        B=config["PAR"]["B"],
#                        beta=config["PAR"]["beta"])

# # Create PyTorch dataloaders for train and validation data
# dataloader_train = DataLoader(dataset_train, batch_size=config["TRAINING"]["BATCH_SIZE"],
#                               shuffle=True, num_workers=1, pin_memory=True)
# dataloader_val = DataLoader(dataset_val, batch_size=config["TRAINING"]["BATCH_SIZE"],
#                             shuffle=False, num_workers=1, pin_memory=True)

# %%
# for (x1, x1out, x2, x2out, dt, Da) in dataloader_train:
#     print(x1[0,:10])
#     print(x1out[0,:10])
#     print(x2[0,:10])
#     print(x2out[0,:10])
